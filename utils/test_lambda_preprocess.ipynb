# %%
stop = set([
    'a',
    'about',
    'above',
    'across',
    'after',
    'afterwards',
    'again',
    'against',
    'ain',
    'all',
    'almost',
    'alone',
    'along',
    'already',
    'also',
    'although',
    'always',
    'am',
    'among',
    'amongst',
    'amoungst',
    'amount',
    'an',
    'and',
    'another',
    'any',
    'anyhow',
    'anyone',
    'anything',
    'anyway',
    'anywhere',
    'are',
    'aren',
    'around',
    'as',
    'at',
    'back',
    'be',
    'became',
    'because',
    'become',
    'becomes',
    'becoming',
    'been',
    'before',
    'beforehand',
    'behind',
    'being',
    'below',
    'beside',
    'besides',
    'between',
    'beyond',
    'bill',
    'both',
    'bottom',
    'but',
    'by',
    'call',
    'can',
    'cannot',
    'cant',
    'co',
    'con',
    'could',
    'couldn',
    'couldnt',
    'cry',
    'd',
    'de',
    'describe',
    'detail',
    'did',
    'didn',
    'do',
    'does',
    'doesn',
    'doing',
    'don',
    'done',
    'down',
    'due',
    'during',
    'each',
    'eg',
    'eight',
    'either',
    'eleven',
    'else',
    'elsewhere',
    'empty',
    'enough',
    'etc',
    'even',
    'ever',
    'every',
    'everyone',
    'everything',
    'everywhere',
    'except',
    'few',
    'fifteen',
    'fify',
    'fill',
    'find',
    'fire',
    'first',
    'five',
    'for',
    'former',
    'formerly',
    'forty',
    'found',
    'four',
    'from',
    'front',
    'full',
    'further',
    'get',
    'give',
    'go',
    'had',
    'hadn',
    'has',
    'hasn',
    'hasnt',
    'have',
    'haven',
    'having',
    'he',
    'hence',
    'her',
    'here',
    'hereafter',
    'hereby',
    'herein',
    'hereupon',
    'hers',
    'herself',
    'him',
    'himself',
    'his',
    'how',
    'however',
    'hundred',
    'i',
    'ie',
    'if',
    'in',
    'inc',
    'indeed',
    'interest',
    'into',
    'is',
    'isn',
    'it',
    'its',
    'itself',
    'just',
    'keep',
    'last',
    'latter',
    'latterly',
    'least',
    'less',
    'll',
    'ltd',
    'm',
    'ma',
    'made',
    'many',
    'may',
    'me',
    'meanwhile',
    'might',
    'mightn',
    'mill',
    'mine',
    'more',
    'moreover',
    'most',
    'mostly',
    'move',
    'much',
    'must',
    'mustn',
    'my',
    'myself',
    'name',
    'namely',
    'needn',
    'neither',
    'never',
    'nevertheless',
    'next',
    'nine',
    'no',
    'nobody',
    'none',
    'noone',
    'nor',
    'not',
    'nothing',
    'now',
    'nowhere',
    'o',
    'of',
    'off',
    'often',
    'on',
    'once',
    'one',
    'only',
    'onto',
    'or',
    'other',
    'others',
    'otherwise',
    'our',
    'ours',
    'ourselves',
    'out',
    'over',
    'own',
    'part',
    'per',
    'perhaps',
    'please',
    'put',
    'rather',
    're',
    's',
    'same',
    'see',
    'seem',
    'seemed',
    'seeming',
    'seems',
    'serious',
    'several',
    'shan',
    'she',
    'should',
    'shouldn',
    'show',
    'side',
    'since',
    'sincere',
    'six',
    'sixty',
    'so',
    'some',
    'somehow',
    'someone',
    'something',
    'sometime',
    'sometimes',
    'somewhere',
    'still',
    'such',
    'system',
    't',
    'take',
    'ten',
    'than',
    'that',
    'the',
    'their',
    'theirs',
    'them',
    'themselves',
    'then',
    'thence',
    'there',
    'thereafter',
    'thereby',
    'therefore',
    'therein',
    'thereupon',
    'these',
    'they',
    'thick',
    'thin',
    'third',
    'this',
    'those',
    'though',
    'three',
    'through',
    'throughout',
    'thru',
    'thus',
    'to',
    'together',
    'too',
    'top',
    'toward',
    'towards',
    'twelve',
    'twenty',
    'two',
    'un',
    'under',
    'until',
    'up',
    'upon',
    'us',
    've',
    'very',
    'via',
    'was',
    'wasn',
    'we',
    'well',
    'were',
    'weren',
    'what',
    'whatever',
    'when',
    'whence',
    'whenever',
    'where',
    'whereafter',
    'whereas',
    'whereby',
    'wherein',
    'whereupon',
    'wherever',
    'whether',
    'which',
    'while',
    'whither',
    'who',
    'whoever',
    'whole',
    'whom',
    'whose',
    'why',
    'will',
    'with',
    'within',
    'without',
    'won',
    'would',
    'wouldn',
    'y',
    'yet',
    'you',
    'your',
    'yours',
    'yourself',
    'yourselves'
])

# %%
import json
from transformers import pipeline
import re


model_sent = "philschmid/distilbert-base-multilingual-cased-sentiment-2"
model_sum = "sshleifer/distilbart-xsum-12-3"
model_sent_path = f"{model_sent}"
model_sum_path = f"{model_sum}"

nlp_sent = pipeline("sentiment-analysis", model = model_sent_path, tokenizer = model_sent_path)
nlp_sum = pipeline("summarization", model = model_sum_path, tokenizer = model_sum_path)

# %%
def lambda_handler(raw_text):

    email = parse_email(raw_text)
    text = clean_text(email["body"])


    sentiment = nlp_sent(text, top_k = None)

    n = len(text.split(" "))
    if n > 62*2:
        summary =  nlp_sum(text)[0]['summary_text']
    elif n > 10:
        summary = nlp_sum(text, max_length = round(n/1.5))[0]['summary_text']
    else:
        summary = text

    ans = {"summary" : summary, "sentiment" : sentiment, "email" : email}
    return ans

# %%
lambda_handler("""This is
a sample
input text""")
# Out:
# {'summary': 'this sample input text',
#  'sentiment': [{'label': 'negative', 'score': 0.7871692776679993},
#   {'label': 'neutral', 'score': 0.12109148502349854},
#   {'label': 'positive', 'score': 0.09173920750617981}],
#  'email': {'body': 'This is a sample input text '}}

# %%
def parse_email(raw_text):
    fields = ['Message-ID','Date','From','To','Subject','X-FileName']
    lines = raw_text.split('\n')
    email={}
    body=''
    field = ''
    last_field = ''
    value = ''
    key = None
    for line in lines:
        for field in fields:
            if (field in line) & (last_field != 'X-FileName'):
                pair = line.split(':',1)
                if pair[0] != field:
                    break
                key = pair[0].lower()
                value = pair[1].strip()
                email[key] = value
                last_field = field
                break
            else:
                if last_field == 'X-FileName':
                    body += ' ' + line.strip()
                    email['body'] = body
                    break
                elif ':' in line:
                    if field == 'X-FileName':
                        pair = line.split(':',1)
                        if pair[0] != field:
                            break
                        key = pair[0].lower()
                        value = pair[1].strip()
                        email[key] = value
                        last_field = field
                        break
                    else:
                        continue
                else:
                    if line != '' or value != '':
                        if key is None or key == 'NoField':
                            key = 'NoField'
                            line += " "
                        value += line
                        email[key] = value
                    break

    if 'body' not in email:
        if 'NoField' in email:
            email['body'] = email['NoField']
            del email['NoField']
    return email

# %%
text = """
Message-ID: <2687772.1075861909475.JavaMail.evans@thyme>
Date: Tue, 9 Oct 2001 07:14:32 -0700 (PDT)
From: toby.kuehl@enron.com
To: jean.adams@enron.com, patrick.barry@enron.com, robert.benningfield@enron.com, 
	larry.berger@enron.com, ramona.betancourt@enron.com, 
	legale.black@enron.com, jean.blair@enron.com, 
	michael.bodnar@enron.com, sharon.brown@enron.com, 
	randy.bryan@enron.com, john.buchanan@enron.com, 
	craig.buehler@enron.com, nancy.callans@enron.com, 
	james.carr@enron.com, karen.clapper@enron.com, 
	martha.cormier@enron.com, mary.draemer@enron.com, 
	tangie.dykes@enron.com, jodie.floyd@enron.com, 
	sherry.forbish@enron.com, ava.garcia@enron.com, 
	chris.greaney@enron.com, bert.hernandez@enron.com, 
	scott.hibbard@enron.com, randy.janzen@enron.com, 
	tammy.jaquet@enron.com, terry.kowalke@enron.com, 
	toby.kuehl@enron.com, joe.linhart@enron.com, 
	maryann.locknar@enron.com, maggie.matheson@enron.com, 
	janet.mcdaniel@enron.com, gerry.medeles@enron.com, 
	vernon.mercaldo@enron.com, beverly.miller@enron.com, 
	amy.mulligan@enron.com, renee.perry@enron.com, 
	diana.porter@enron.com, dale.ratliff@enron.com, 
	cynthia.rivers@enron.com, darrell.schoolcraft@enron.com, 
	debra.scurlock@enron.com, gary.spraggins@enron.com, 
	kathy.sturr@enron.com, kay.threet@enron.com, cara.vaughan@enron.com, 
	shirley.walden@enron.com, linda.ward@enron.com, 
	kathy.washington@enron.com, jerry.wilkens@enron.com, 
	ricki.winters@enron.com, harry.woodson@enron.com, 
	raetta.zadow@enron.com
Subject: Carlton Resolution 2001-2002
Cc: mary.darveaux@enron.com, lynn.blair@enron.com, steven.january@enron.com, 
	gary.spraggins@enron.com, deborah.dunten@enron.com, 
	theresa.hess@enron.com, kim.perez@enron.com, 
	gerald.skertich@enron.com, james.studebaker@enron.com, 
	mike.barry@enron.com, joni.bollinger@enron.com, 
	janet.bowers@enron.com, lorna.brennan@enron.com, 
	deborah.cappiello@enron.com, bill.fowler@enron.com, 
	steve.gilbert@enron.com, rosemary.gracey@enron.com, 
	connie.hook@enron.com, tim.johanson@enron.com, 
	karen.lagerstrom@enron.com, laura.lantefield@enron.com, 
	julie.mccoy@enron.com, w..mcgowan@enron.com, kent.miller@enron.com, 
	dave.neubauer@enron.com, frank.oldenhuis@enron.com, 
	larry.pavlou@enron.com, loren.penkava@enron.com, 
	chris.sebesta@enron.com, larry.swett@enron.com, 
	chuck.wilkinson@enron.com, jo.williams@enron.com, 
	frank.semin@enron.com, bob.stevens@enron.com, lisa.valley@enron.com, 
	theresa.branney@enron.com, sue.neville@enron.com, 
	maria.perales@enron.com
Mime-Version: 1.0
Content-Type: text/plain; charset=us-ascii
Content-Transfer-Encoding: 7bit
Bcc: mary.darveaux@enron.com, lynn.blair@enron.com, steven.january@enron.com, 
	gary.spraggins@enron.com, deborah.dunten@enron.com, 
	theresa.hess@enron.com, kim.perez@enron.com, 
	gerald.skertich@enron.com, james.studebaker@enron.com, 
	mike.barry@enron.com, joni.bollinger@enron.com, 
	janet.bowers@enron.com, lorna.brennan@enron.com, 
	deborah.cappiello@enron.com, bill.fowler@enron.com, 
	steve.gilbert@enron.com, rosemary.gracey@enron.com, 
	connie.hook@enron.com, tim.johanson@enron.com, 
	karen.lagerstrom@enron.com, laura.lantefield@enron.com, 
	julie.mccoy@enron.com, w..mcgowan@enron.com, kent.miller@enron.com, 
	dave.neubauer@enron.com, frank.oldenhuis@enron.com, 
	larry.pavlou@enron.com, loren.penkava@enron.com, 
	chris.sebesta@enron.com, larry.swett@enron.com, 
	chuck.wilkinson@enron.com, jo.williams@enron.com, 
	frank.semin@enron.com, bob.stevens@enron.com, lisa.valley@enron.com, 
	theresa.branney@enron.com, sue.neville@enron.com, 
	maria.perales@enron.com
X-From: Kuehl, Toby </O=ENRON/OU=NA/CN=RECIPIENTS/CN=TKUEHL>
X-To: Adams, Jean </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Jadams1>, Barry, Patrick </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Pbarry>, Benningfield, Robert </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Rbennin>, Berger, Larry </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Lberger>, Betancourt, Ramona  </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Rbetanc>, Black, Legale  </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Lblack2>, Blair, Jean </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Jblair>, Bodnar, Michael </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Mbodnar>, Brown, Sharon </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Sbrown1>, Bryan, Randy </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Rbryan2>, Buchanan, John </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Jbuchan2>, Buehler, Craig </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Cbuehle>, Callans, Nancy </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Ncallan>, Carr, James </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Jcarr2>, Clapper, Karen </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Kclappe>, Cormier, Martha </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Mcormie>, Draemer, Mary  </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Mdraeme>, Dykes, Tangie </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Tdykes>, Floyd, Jodie </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Jfloyd>, Forbish, Sherry </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Sforbis>, Garcia, Ava </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Agarcia6>, Greaney, Chris </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Cgreane>, Hernandez, Bert </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Ahernan>, Hibbard, Scott </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Shibbard>, Janzen, Randy </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Rjanzen>, Jaquet, Tammy </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Tjaquet>, Kowalke, Terry </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Tkowalk>, Kuehl, Toby </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Tkuehl>, Linhart, Joe </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Jlinhar>, Locknar, MaryAnn <MaryAnn.Locknar@ENRON.com>, Matheson, Maggie </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Mmathes>, McDaniel, Janet </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Jmcdani>, Medeles, Gerry </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Gmedele>, Mercaldo, Vernon </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Vmercal>, Miller, Beverly </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Bmiller1>, Mulligan, Amy </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Amullig>, Perry, Renee </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Kperry>, Porter, Diana </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Dporter1>, Ratliff, Dale </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Dratlif>, Rivers, Cynthia </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Crivers>, Schoolcraft, Darrell </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Dschool>, Scurlock, Debra </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Dscurloc>, Spraggins, Gary </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Gspragg>, Sturr, Kathy </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Ksturr>, Threet, Kay </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Kthreet>, Vaughan, Cara </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Cvaughan>, Walden, Shirley </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Swalden>, Ward, Linda </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Lward>, Washington, Kathy </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Kwashin>, Wilkens, Jerry </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Jwilken>, Winters, Ricki </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Rwinter>, Woodson, Harry </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Hwoodso>, Zadow, Raetta </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Rzadow>
X-cc: Darveaux, Mary </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Mdarvea>, Blair, Lynn </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Lblair>, January, Steven </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Sjanuary>, Spraggins, Gary </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Gspragg>, Dunten, Deborah </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Ddunten>, Hess, Theresa </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Thess>, Perez, Kim </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Kperez>, Skertich, Gerald </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Gskertic>, Studebaker, James  </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Jstudeb>, Barry, Mike </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Mbarry>, Bollinger, Joni </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Jbollin>, Bowers, Janet </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Jbowers>, Brennan, Lorna </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Lbrenna>, Cappiello, Deborah </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Dcappie>, Fowler, Bill </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Bfowler>, Gilbert, Steve </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Sgilbe2>, Gracey, Rosemary </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Rgracey>, Hook, Connie </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Chook>, Johanson, Tim </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Tjohans>, Lagerstrom, Karen </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Klagers>, Lantefield, Laura </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Llantef>, McCoy, Julie </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Jmccoy>, McGowan, Mike W. </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Mmcgowa>, Miller, Kent </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Kmiller2>, Neubauer, Dave </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Dneubau>, Oldenhuis, Frank </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Foldenhu>, Pavlou, Larry </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Lpavlou>, Penkava, Loren </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Lpenkav>, Sebesta, Chris </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Csebest2>, Swett, Larry </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Lswett>, Wilkinson, Chuck </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Cwilkin>, Williams, Jo </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Jwillia3>, Semin, Frank </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Fsemin>, Stevens, Bob </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Bsteven2>, Valley, Lisa </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Lvalley>, Branney, Theresa </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Tbranne>, Neville, Sue </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Snevill1>, Perales, Maria </O=ENRON/OU=NA/CN=RECIPIENTS/CN=Mperale>
X-bcc: 
X-Folder: \LBLAIR (Non-Privileged)\Blair, Lynn\Carlton Resolution
X-Origin: Blair-L
X-FileName: LBLAIR (Non-Privileged).pst

The attached Total Carlton Resolution for 2001-2002 was posted today 10/9/01 <http://www.nng.enron.com/dob/etfr_carlton.html>

Toby
"""

# %%
text = "this is a sample text"
parse_email(text)
# Out:
# {'body': 'this is a sample text '}

# %%
def clean_text(data):
    data = str(data)
    if data is not None:
        data = ' '.join([word for word in data.split() if word not in stop])
        data = data.lower()
        data = re.sub('\W+',' ', data)
        return data.strip()
    return ''

# %%
#text = "this is a sample text"
clean_text(parse_email(text)['body'])
# Out:
# 'the attached total carlton resolution 2001 2002 posted today 10 9 01 http www nng enron com dob etfr_carlton html toby'
